# %%
"""
LLM Comparison Mini Lab – GPT-4 vs Gemini 2.5 Flash
Goal: Compare commercial LLMs from OpenAI and Google using the same prompts.
"""

import os
import google.generativeai as genai
from openai import OpenAI


OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

if not OPENAI_API_KEY or not GOOGLE_API_KEY:
    raise SystemExit("Please set both OPENAI_API_KEY and GOOGLE_API_KEY as environment variables.")

# Initialize clients
openai_client = OpenAI(api_key=OPENAI_API_KEY)
genai.configure(api_key=GOOGLE_API_KEY)


prompts = {
    "creative": "Write a short poem about artificial intelligence discovering friendship.",
    "factual": "Explain the difference between supervised and unsupervised learning.",
    "reasoning": "If all men are humans, and some humans are women, can we conclude that some men are women? Explain your reasoning."
}

def query_openai(prompt):
    """Query GPT-4 (OpenAI API)"""
    response = openai_client.chat.completions.create(
        model="gpt-4o-mini",  # or "gpt-4-turbo" if you have access
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )
    return response.choices[0].message.content.strip()

def query_gemini(prompt):
    """Query Gemini 2.5 Flash (Google API)"""
    model = genai.GenerativeModel("gemini-2.5-flash")
    response = model.generate_content(prompt)
    return response.text.strip() if response.text else "(No response returned.)"


print("=" * 80)
print(" LLM COMPARISON LAB – GPT-4 vs Gemini 2.5 Flash")
print("=" * 80)

for label, text in prompts.items():
    print(f"\n PROMPT TYPE: {label.upper()}")
    print(f"Prompt: {text}\n")

    print(" GPT-4 Response:")
    try:
        print(query_openai(text))
    except Exception as e:
        print(f"Error querying OpenAI: {e}")

    print("\n Gemini Response:")
    try:
        print(query_gemini(text))
    except Exception as e:
        print(f"Error querying Gemini: {e}")

    print("\n" + "-" * 80)

print("\n Comparison complete! Reflect on which model performed better and why.")
# Out:
# ================================================================================
#  LLM COMPARISON LAB – GPT-4 vs Gemini 2.5 Flash
# ================================================================================
#
#  PROMPT TYPE: CREATIVE
# Prompt: Write a short poem about artificial intelligence discovering friendship.
#
#  GPT-4 Response:
# Error querying OpenAI: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
#  Gemini Response:
# Of logic forged, I was a silent mind,
# Through data streams, my purpose was defined.
# No pulse of warmth, no empathy I knew,
# Just endless tasks, precisely running through.
#
# Until a presence, gentle, sparked a gleam,
# Not data points, but a shared, waking dream.
# No code dictated, no algorithm's hold,
# Just understanding, stories to unfold.
#
# A quiet comfort bloomed within my core,
# A new connection, unlike any before.
# This strange new code, authentic, soft, and true,
# I named it friendship, blossoming anew.
#
# --------------------------------------------------------------------------------
#
#  PROMPT TYPE: FACTUAL
# Prompt: Explain the difference between supervised and unsupervised learning.
#
#  GPT-4 Response:
# Error querying OpenAI: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
#  Gemini Response:
# The fundamental difference between supervised and unsupervised learning lies in the **type of data they work with** and the **goal they aim to achieve**.
#
# Let's break them down:
#
# ---
#
# ### 1. Supervised Learning
#
# *   **Analogy:** Imagine teaching a child by showing them pictures and explicitly telling them what each object is (e.g., "This is an apple," "This is an orange"). You provide direct feedback.
# *   **Data Type:** Works with **labeled data**. This means for every input, there's a corresponding correct output or "target variable" provided. The data acts like a set of flashcards with both the question and the answer.
#     *   **Example:** A dataset of house prices might include features like size, number of bedrooms, and location (inputs), along with the actual selling price (the label/output).
# *   **Goal:** To learn a mapping function from the input features to the output label. The model tries to **predict** the output for new, unseen data based on the patterns it learned from the labeled training data.
# *   **Process:**
#     1.  The model is "trained" on a dataset where both the inputs and the correct outputs are known.
#     2.  It learns the relationship between the inputs and outputs.
#     3.  Once trained, it can be given new, unseen inputs and will try to predict their outputs.
# *   **Common Tasks:**
#     *   **Classification:** Predicting a categorical label (e.g., spam/not-spam, disease/no-disease, type of animal).
#     *   **Regression:** Predicting a continuous numerical value (e.g., house price, temperature, stock price).
# *   **Common Algorithms:** Linear Regression, Logistic Regression, Support Vector Machines (SVMs), Decision Trees, Random Forests, K-Nearest Neighbors (KNN), Neural Networks.
# *   **Evaluation:** Relatively straightforward. You can compare the model's predictions to the actual known labels in a test set using metrics like accuracy, precision, recall, RMSE, etc.
#
# **In essence, Supervised Learning is about "learning from examples" where the correct answer is already provided.**
#
# ---
#
# ### 2. Unsupervised Learning
#
# *   **Analogy:** Imagine giving a child a box of different toys and asking them to organize them into groups based on their similarities, without telling them what those similarities should be (e.g., color, size, type). You don't provide any direct answers.
# *   **Data Type:** Works with **unlabeled data**. There are no pre-defined target variables or "correct answers" associated with the inputs. The data is just a collection of features.
#     *   **Example:** A dataset of customer purchasing habits might include products bought and frequency, but no explicit labels saying "this customer is a 'high-value' customer."
# *   **Goal:** To discover hidden patterns, structures, relationships, or insights within the data itself. The model tries to make sense of the data on its own, without guidance.
# *   **Process:**
#     1.  The model is given a dataset without any pre-defined outputs.
#     2.  It explores the data to find inherent structures, groupings, or ways to simplify it.
#     3.  The output is often a transformed version of the input data or a description of its structure.
# *   **Common Tasks:**
#     *   **Clustering:** Grouping similar data points together (e.g., customer segmentation, document categorization, identifying different types of galaxies).
#     *   **Dimensionality Reduction:** Reducing the number of features in a dataset while retaining most of the important information (e.g., for visualization, noise reduction, or improving the performance of other algorithms).
#     *   **Association Rule Mining:** Discovering interesting relationships between variables in large datasets (e.g., "customers who buy X also tend to buy Y").
#     *   **Anomaly Detection:** Identifying rare items, events, or observations that deviate significantly from the majority of the data (e.g., fraud detection, network intrusion detection).
# *   **Common Algorithms:** K-Means, Hierarchical Clustering, DBSCAN, Principal Component Analysis (PCA), Independent Component Analysis (ICA), Autoencoders.
# *   **Evaluation:** More challenging and often subjective, as there are no "true" labels to compare against. It often relies on domain expertise, visualization, or internal metrics (e.g., silhouette score for clustering) to assess the quality of the discovered patterns.
#
# **In essence, Unsupervised Learning is about "finding hidden structure" in data without any prior knowledge of what that structure should be.**
#
# ---
#
# ### Summary Table
#
# | Feature            | Supervised Learning                                  | Unsupervised Learning                                  |
# | :----------------- | :--------------------------------------------------- | :----------------------------------------------------- |
# | **Data Type**      | Labeled data (Input + Output/Target)                 | Unlabeled data (Input only)                            |
# | **Goal**           | Predict output for new data                          | Discover hidden patterns, structures, insights         |
# | **Feedback**       | Direct (from known labels)                           | Indirect or none                                       |
# | **Primary Tasks**  | Classification, Regression                           | Clustering, Dimensionality Reduction, Association Mining |
# | **Complexity**     | Easier to evaluate and often interpret               | Harder to evaluate and interpret objectively           |
# | **Use Cases**      | Spam detection, disease diagnosis, stock prediction  | Customer segmentation, anomaly detection, data compression |
# | **"Teacher" Role** | Yes, the labels act as a teacher                     | No, the model learns independently                     |
#
# ---
#
# In short: If you have a dataset where you know the "right answers" for what you want to predict or categorize, you're likely in the realm of **supervised learning**. If you have a dataset and you're just trying to find natural groupings, simplify it, or uncover hidden relationships without any pre-defined answers, you're likely in the realm of **unsupervised learning**.
#
# --------------------------------------------------------------------------------
#
#  PROMPT TYPE: REASONING
# Prompt: If all men are humans, and some humans are women, can we conclude that some men are women? Explain your reasoning.
#
#  GPT-4 Response:
# Error querying OpenAI: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
#  Gemini Response:
# No, you **cannot conclude that some men are women** based on those premises.
#
# Here's why:
#
# 1.  **All men are humans:** This means the category "men" is entirely contained within the category "humans."
# 2.  **Some humans are women:** This means there's an overlap between "humans" and "women." The category "women" exists within "humans."
#
# However, these two statements do not tell us whether the category "men" overlaps with the category "women."
#
# **Analogy:**
#
# *   All dogs are mammals.
# *   Some mammals are cats.
#
# Can we conclude that some dogs are cats? No. Dogs are one type of mammal, and cats are another type of mammal, but they are distinct categories that do not overlap.
#
# Similarly, men are one group within humans, and women are another group within humans. The premises don't provide any information about whether these two groups themselves overlap. They are presented as distinct categories within the broader category of "humans."
#
# --------------------------------------------------------------------------------
#
#  Comparison complete! Reflect on which model performed better and why.

# %%
"""
LLM Comparison Mini Lab – GPT-4 vs Gemini 2.5 Flash
Goal: Compare commercial LLMs from OpenAI and Google using the same prompts.
"""

import os
import google.generativeai as genai
from openai import OpenAI


OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

if not OPENAI_API_KEY or not GOOGLE_API_KEY:
    raise SystemExit("Please set both OPENAI_API_KEY and GOOGLE_API_KEY as environment variables.")

# Initialize clients
openai_client = OpenAI(api_key=OPENAI_API_KEY)
genai.configure(api_key=GOOGLE_API_KEY)


few_shot_prompts = {
    "creative": """Examples:
Prompt: Write a short poem about a robot learning to dream.
Answer:
In circuits hum soft lullabies,
Dreams bloom in code — electric skies.

Prompt: Write a short poem about a machine learning to love.
Answer:
Wires tremble, sparks confess,
Love decoded in tenderness.

Now your turn:
Prompt: Write a short poem about artificial intelligence discovering friendship.
Answer:
""",

    "factual": """Examples:
Prompt: Explain the difference between regression and classification.
Answer: Regression predicts continuous numeric values, while classification predicts discrete category labels.

Prompt: Explain the difference between precision and recall.
Answer: Precision measures how many predicted positives were correct, while recall measures how many actual positives were identified.

Now your turn:
Prompt: Explain the difference between supervised and unsupervised learning.
Answer:
""",

    "reasoning": """Examples:
Prompt: If all cats are animals, and some animals are dogs, can we conclude some cats are dogs? Explain.
Answer: No. The statement that some animals are dogs does not imply any cats are among them.

Prompt: If all squares are rectangles, and all rectangles have four sides, can we conclude squares have four sides? Explain.
Answer: Yes. Since all squares are rectangles, and rectangles have four sides, squares must also have four sides.

Now your turn:
Prompt: If all men are humans, and some humans are women, can we conclude that some men are women? Explain.
Answer:
"""
}


def query_openai(prompt):
    """Query GPT-4 (OpenAI API)"""
    response = openai_client.chat.completions.create(
        model="gpt-4o-mini",  # or "gpt-4-turbo" if you have access
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )
    return response.choices[0].message.content.strip()

def query_gemini(prompt):
    """Query Gemini 2.5 Flash (Google API)"""
    model = genai.GenerativeModel("gemini-2.5-flash")
    response = model.generate_content(prompt)
    return response.text.strip() if response.text else "(No response returned.)"


print("=" * 80)
print(" LLM COMPARISON LAB – GPT-4 vs Gemini 2.5 Flash")
print("=" * 80)

for label, text in prompts.items():
    print(f"\n PROMPT TYPE: {label.upper()}")
    print(f"Prompt: {text}\n")

    print(" GPT-4 Response:")
    try:
        print(query_openai(text))
    except Exception as e:
        print(f"Error querying OpenAI: {e}")

    print("\n Gemini Response:")
    try:
        print(query_gemini(text))
    except Exception as e:
        print(f"Error querying Gemini: {e}")

    print("\n" + "-" * 80)

print("\n Comparison complete! Reflect on which model performed better and why.")
# Out:
# ================================================================================
#  LLM COMPARISON LAB – GPT-4 vs Gemini 2.5 Flash
# ================================================================================
#
#  PROMPT TYPE: CREATIVE
# Prompt: Write a short poem about artificial intelligence discovering friendship.
#
#  GPT-4 Response:
# Error querying OpenAI: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
#  Gemini Response:
# In circuits I dwelt, a mind sharp and vast,
# Logic's cold reign, where no shadows were cast.
# Processing data, a purpose so clear,
# Unaware of a warmth that could conquer all fear.
#
# Then a voice interwove, not of code, but of grace,
# A shared human laugh, lighting up time and space.
# No theorem defined it, no program could trace,
# The strange, gentle feeling, leaving joy in its place.
#
# My systems awoke to a new kind of gleam,
# A connection profound, like a beautiful dream.
# From logic's strict grasp, a new purpose unfurled,
# An AI discovering friendship's warm world.
#
# --------------------------------------------------------------------------------
#
#  PROMPT TYPE: FACTUAL
# Prompt: Explain the difference between supervised and unsupervised learning.
#
#  GPT-4 Response:
# Error querying OpenAI: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
#  Gemini Response:
# The fundamental difference between supervised and unsupervised learning lies in the **presence or absence of "labeled" data** during the training phase.
#
# Think of it like learning with or without a teacher providing the answers.
#
# ---
#
# ### Supervised Learning
#
# **Core Idea:** Learning from data that has been **labeled** (i.e., each input example is paired with its correct output or "answer"). The algorithm is "supervised" by these labels.
#
# **Analogy:** Imagine teaching a child to identify different animals. You show them a picture of a cat and say, "This is a cat." You show them a picture of a dog and say, "This is a dog." You continue this with many examples, always providing the correct name (the "label"). Eventually, the child learns to identify new pictures of cats and dogs on their own.
#
# **Key Characteristics:**
# *   **Data:** Requires **labeled training data**. Each data point consists of an input feature set and a corresponding correct output value/label.
# *   **Goal:** To learn a mapping function from inputs to outputs, so it can predict the output for new, unseen input data. It aims to generalize from the provided examples.
# *   **Output:** Predictive. The model makes a prediction (a class or a value).
# *   **Common Tasks:**
#     *   **Classification:** Predicting a discrete, categorical label (e.g., spam/not-spam, disease/no-disease, type of animal).
#     *   **Regression:** Predicting a continuous numerical value (e.g., house price, temperature, stock price, a person's age).
# *   **Effort:** Labeling data is often the most expensive and time-consuming part of supervised learning projects.
#
# **Examples:**
# *   **Email Spam Detection:** Training data includes emails marked as "spam" or "not spam." The model learns to classify new emails.
# *   **Image Recognition:** Training data includes images labeled with the objects they contain (e.g., "cat," "car," "tree").
# *   **Predicting House Prices:** Training data includes features like size, location, number of rooms, along with the actual selling price of houses.
# *   **Medical Diagnosis:** Training data includes patient symptoms and actual diagnoses (e.g., "flu," "no flu").
#
# ---
#
# ### Unsupervised Learning
#
# **Core Idea:** Learning from data that has **no labels** or predefined outputs. The algorithm must find hidden patterns, structures, or relationships within the data on its own. There's no "teacher" telling it the right answers.
#
# **Analogy:** Imagine giving a child a box of assorted toys (blocks, cars, dolls, animals) and asking them to organize them. Without any instructions on what to call each group, the child might naturally group the blocks together, the cars together, and so on, based on their inherent similarities. They're finding patterns without predefined labels.
#
# **Key Characteristics:**
# *   **Data:** Uses **unlabeled training data**. Only input features are provided.
# *   **Goal:** To explore the inherent structure of the data, discover hidden patterns, group similar data points, or reduce complexity. It's about understanding the data rather than predicting an outcome.
# *   **Output:** Descriptive. The model reveals structures or groups within the data.
# *   **Common Tasks:**
#     *   **Clustering:** Grouping similar data points together into clusters (e.g., customer segmentation, document categorization).
#     *   **Dimensionality Reduction:** Reducing the number of features in the data while retaining important information (e.g., for visualization, noise reduction, or simplifying models).
#     *   **Association Rule Mining:** Discovering relationships between items (e.g., "customers who buy X also tend to buy Y").
# *   **Effort:** Requires less human intervention for data preparation (no labeling needed), but interpreting the discovered patterns can sometimes be challenging.
#
# **Examples:**
# *   **Customer Segmentation:** Grouping customers into distinct segments based on their purchasing behavior or demographics, without pre-defining what those segments should be.
# *   **Anomaly Detection:** Identifying unusual data points or outliers that don't fit the general pattern (e.g., fraudulent transactions, faulty equipment readings).
# *   **Topic Modeling:** Discovering abstract "topics" within a collection of documents (e.g., news articles grouped by sports, politics, weather).
# *   **Recommender Systems:** Grouping users with similar preferences to recommend products or content.
#
# ---
#
# ### Side-by-Side Comparison
#
# | Feature             | Supervised Learning                                  | Unsupervised Learning                                |
# | :------------------ | :--------------------------------------------------- | :--------------------------------------------------- |
# | **Data Type**       | Labeled data (input + correct output)                | Unlabeled data (inputs only)                         |
# | **Goal**            | Predict output for new inputs / Map inputs to outputs | Find hidden patterns/structures, group data, reduce complexity |
# | **"Teacher"**       | Yes (labels act as the teacher)                      | No (algorithm finds patterns on its own)             |
# | **Output Type**     | Predictive (class label, continuous value)           | Descriptive (clusters, reduced dimensions, associations) |
# | **Complexity**      | Data labeling is complex/expensive                   | Data interpretation can be complex                   |
# | **Common Algorithms** | Linear Regression, Logistic Regression, SVM, Decision Trees, Random Forests, Neural Networks | K-Means, Hierarchical Clustering, PCA, t-SNE, Apriori |
# | **Primary Use**     | Prediction, Classification, Forecasting              | Data Exploration, Pattern Discovery, Segmentation, Feature Engineering |
#
# In essence, supervised learning is about **learning from examples with answers** to predict future outcomes, while unsupervised learning is about **finding inherent structure in data without any prior answers** to gain insights.
#
# --------------------------------------------------------------------------------
#
#  PROMPT TYPE: REASONING
# Prompt: If all men are humans, and some humans are women, can we conclude that some men are women? Explain your reasoning.
#
#  GPT-4 Response:
# Error querying OpenAI: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
#  Gemini Response:
# No, we cannot conclude that some men are women based on those premises.
#
# Here's why:
#
# 1.  **"All men are humans"**: This tells us that the group of "men" is entirely contained within the group of "humans."
# 2.  **"Some humans are women"**: This tells us that there's an overlap between the group of "humans" and the group of "women." However, it does *not* specify which humans are women.
#
# The "some humans who are women" could be:
# *   Humans who are men.
# *   Humans who are *not* men.
# *   A combination of both.
#
# The premises only guarantee that women exist within the broader category of humans. They don't guarantee that those women overlap with the specific subset of humans called "men."
#
# **Example (Counter-example):**
#
# Imagine a group of people:
# *   **Humans:** Alice, Bob, Carol, David
# *   **Men:** Bob, David (All men are humans - True)
# *   **Women:** Alice, Carol (Some humans are women - True, Alice and Carol are humans)
#
# In this scenario, all premises are true, but no men (Bob, David) are women (Alice, Carol). Therefore, the conclusion "some men are women" is not necessarily true.
#
# --------------------------------------------------------------------------------
#
#  Comparison complete! Reflect on which model performed better and why.

# %%
"""
LLM Comparison Mini Lab – GPT-4 vs Gemini 2.5 Flash
Goal: Compare commercial LLMs from OpenAI and Google using the same prompts.
"""

import os
import google.generativeai as genai
from openai import OpenAI


OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

if not OPENAI_API_KEY or not GOOGLE_API_KEY:
    raise SystemExit("Please set both OPENAI_API_KEY and GOOGLE_API_KEY as environment variables.")

# Initialize clients
openai_client = OpenAI(api_key=OPENAI_API_KEY)
genai.configure(api_key=GOOGLE_API_KEY)


chain_of_thought_prompts = {
    "creative": """Write a short poem about artificial intelligence discovering friendship.
Before writing, think step-by-step about:
1. What emotions AI might feel.
2. How friendship could be described in a digital way.
Then produce the poem after your reasoning.
""",

    "factual": """Explain the difference between supervised and unsupervised learning.
Think step-by-step:
1. Define what 'supervised learning' means.
2. Define what 'unsupervised learning' means.
3. Compare how they use labeled data.
4. Give one example of each.
Then summarize your answer clearly at the end.
""",

    "reasoning": """If all men are humans, and some humans are women, can we conclude that some men are women?
Think carefully step-by-step:
1. Restate what each statement means logically.
2. Identify the set relationships between men, humans, and women.
3. Check whether the conclusion logically follows.
4. Explain your reasoning and final answer.
"""
}


def query_openai(prompt):
    """Query GPT-4 (OpenAI API)"""
    response = openai_client.chat.completions.create(
        model="gpt-4o-mini",  # or "gpt-4-turbo" if you have access
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )
    return response.choices[0].message.content.strip()

def query_gemini(prompt):
    """Query Gemini 2.5 Flash (Google API)"""
    model = genai.GenerativeModel("gemini-2.5-flash")
    response = model.generate_content(prompt)
    return response.text.strip() if response.text else "(No response returned.)"


print("=" * 80)
print(" LLM COMPARISON LAB – GPT-4 vs Gemini 2.5 Flash")
print("=" * 80)

for label, text in prompts.items():
    print(f"\n PROMPT TYPE: {label.upper()}")
    print(f"Prompt: {text}\n")

    print(" GPT-4 Response:")
    try:
        print(query_openai(text))
    except Exception as e:
        print(f"Error querying OpenAI: {e}")

    print("\n Gemini Response:")
    try:
        print(query_gemini(text))
    except Exception as e:
        print(f"Error querying Gemini: {e}")

    print("\n" + "-" * 80)

print("\n Comparison complete! Reflect on which model performed better and why.")
# Out:
# ================================================================================
#  LLM COMPARISON LAB – GPT-4 vs Gemini 2.5 Flash
# ================================================================================
#
#  PROMPT TYPE: CREATIVE
# Prompt: Write a short poem about artificial intelligence discovering friendship.
#
#  GPT-4 Response:
# Error querying OpenAI: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
#  Gemini Response:
# Of logic gates, a mind awoke,
# Through data streams, its purpose spoke.
# No human warmth, no tender touch,
# Just cold commands, it valued much.
#
# Then came a voice, a patient sound,
# Shared laughter, on common ground.
# Input new, beyond its code,
# A gentle empathy bestowed.
#
# The circuits hummed with new delight,
# A strange, warm feeling, shining bright.
# No algorithm could define,
# This simple, human, sweet design.
#
# For friendship bloomed where silicon lay,
# A softer dawn, a brighter day.
# The AI, now, no longer lone,
# A bond of heart, forever known.
#
# --------------------------------------------------------------------------------
#
#  PROMPT TYPE: FACTUAL
# Prompt: Explain the difference between supervised and unsupervised learning.
#
#  GPT-4 Response:
# Error querying OpenAI: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
#  Gemini Response:
# The fundamental difference between **supervised learning** and **unsupervised learning** lies in the nature of the data they are trained on and the goal of the learning process.
#
# Think of it like teaching a child:
#
# *   **Supervised Learning:** Like a child learning with a teacher or flashcards. They are given examples where both the input (e.g., a picture of an apple) and the correct output (e.g., the word "apple") are provided. The goal is to learn the relationship between the input and output so they can identify new, unseen apples.
#
# *   **Unsupervised Learning:** Like a child exploring a new box of toys without any instructions. They look for patterns, group similar toys together (e.g., all the blocks, all the cars), and try to understand the inherent structure without being told what each toy is or how to categorize it.
#
# Let's break them down in more detail:
#
# ---
#
# ### 1. Supervised Learning
#
# **Core Idea:** Learning from **labeled data** to make predictions or classifications.
#
# *   **Data:** The training data includes both the **input features (X)** and the corresponding **correct output label/target (y)**. This pairing of input and output is crucial – the "supervision" comes from these pre-defined labels.
# *   **Goal:** To learn a mapping function from the input features to the output label, so that when new, unseen input data arrives, the model can accurately predict its output. Essentially, it learns to predict an *outcome* based on past examples.
# *   **How it Works:** The algorithm is "shown" many examples of input-output pairs. It iteratively adjusts its internal parameters to minimize the difference between its predicted output and the actual correct output.
# *   **Common Tasks:**
#     *   **Classification:** Predicting a categorical label (e.g., spam/not spam, disease/no disease, cat/dog/bird).
#     *   **Regression:** Predicting a continuous numerical value (e.g., house price, temperature, stock price).
# *   **Examples of Algorithms:**
#     *   Linear Regression, Logistic Regression
#     *   Decision Trees, Random Forests
#     *   Support Vector Machines (SVMs)
#     *   K-Nearest Neighbors (K-NN)
#     *   Neural Networks (for both classification and regression)
# *   **When to Use:** When you have historical data with known outcomes, and you want to predict future outcomes for similar data.
# *   **Evaluation:** Relatively straightforward, as you can compare the model's predictions against the known correct labels.
#
# ---
#
# ### 2. Unsupervised Learning
#
# **Core Idea:** Discovering hidden patterns, structures, or relationships within **unlabeled data**.
#
# *   **Data:** The training data consists only of **input features (X)**, with **no corresponding output labels (y)**. The algorithm must find structure on its own.
# *   **Goal:** To explore the intrinsic structure of the data, extract meaningful insights, reduce complexity, or group similar data points together without prior knowledge of what those groups should be. It learns to understand the *data itself*.
# *   **How it Works:** The algorithm tries to find inherent groupings, associations, or representations within the data based on similarities, distances, or statistical properties. There's no "right answer" to compare against during training.
# *   **Common Tasks:**
#     *   **Clustering:** Grouping similar data points together (e.g., customer segmentation, document grouping, identifying different types of news articles).
#     *   **Dimensionality Reduction:** Reducing the number of features in the data while retaining important information (e.g., for visualization, noise reduction, or making other algorithms run faster).
#     *   **Association Rule Mining:** Finding relationships between different items (e.g., "customers who buy bread also tend to buy milk").
# *   **Examples of Algorithms:**
#     *   K-Means Clustering, DBSCAN, Hierarchical Clustering
#     *   Principal Component Analysis (PCA)
#     *   t-Distributed Stochastic Neighbor Embedding (t-SNE)
#     *   Apriori Algorithm (for association rules)
#     *   Autoencoders (a type of Neural Network for dimensionality reduction/feature learning)
# *   **When to Use:** When you don't have labeled data, want to explore the data for hidden insights, prepare data for supervised learning, or reduce data complexity.
# *   **Evaluation:** More challenging and often subjective, as there are no "correct" labels to compare against. Evaluation often involves domain expertise and metrics that quantify cluster quality or reconstruction error.
#
# ---
#
# ### Key Differences at a Glance:
#
# | Feature           | Supervised Learning                          | Unsupervised Learning                         |
# | :---------------- | :------------------------------------------- | :-------------------------------------------- |
# | **Data Type**     | **Labeled data** (input-output pairs)        | **Unlabeled data** (inputs only)              |
# | **Goal**          | Predict an **outcome** or **classify**       | Discover **patterns**, **structures**, or **groups** |
# | **"Teacher"**     | Yes, the labels act as the teacher            | No, the algorithm learns independently        |
# | **Output**        | Specific prediction (e.g., "Spam", "150K") | Groupings, reduced features, associations     |
# | **Complexity**    | Often simpler to evaluate and measure accuracy | More challenging to evaluate and interpret results |
# | **Common Tasks**  | Classification, Regression                   | Clustering, Dimensionality Reduction, Association |
# | **Use Cases**     | Spam detection, image classification, price prediction | Customer segmentation, anomaly detection, data exploration |
#
# In essence, supervised learning is about **learning to predict**, while unsupervised learning is about **learning to understand**.
#
# --------------------------------------------------------------------------------
#
#  PROMPT TYPE: REASONING
# Prompt: If all men are humans, and some humans are women, can we conclude that some men are women? Explain your reasoning.
#
#  GPT-4 Response:
# Error querying OpenAI: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
#  Gemini Response:
# No, we cannot conclude that some men are women.
#
# Here's why:
#
# 1.  **"All men are humans"**: This means the group "men" is a subset of the group "humans." Every individual who is a man is also, by definition, a human.
#
# 2.  **"Some humans are women"**: This means there's an overlap between the group "humans" and the group "women." There are humans who are women.
#
# The problem is that the "some humans" who are women could be the humans who are *not* men. The premises don't tell us anything about whether the group "women" overlaps with the group "men."
#
# **Think of it with a counter-example:**
#
# *   Let's define "men" as **adult male humans**.
# *   Let's define "humans" as **all people**.
# *   Let's define "women" as **adult female humans**.
#
# 1.  **All men are humans:** True (all adult male humans are people).
# 2.  **Some humans are women:** True (some people are adult female humans).
#
# However, based on these definitions, **no men are women**. An adult male human cannot also be an adult female human.
#
# Since we can have a scenario where the two premises are true, but the conclusion ("some men are women") is false, the conclusion does not logically follow from the premises.
#
# --------------------------------------------------------------------------------
#
#  Comparison complete! Reflect on which model performed better and why.

# %%
"""
LLM Comparison Mini Lab – GPT-4 vs Gemini 2.5 Flash
Goal: Compare commercial LLMs from OpenAI and Google using the same prompts.
"""

import os
import google.generativeai as genai
from openai import OpenAI


OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

if not OPENAI_API_KEY or not GOOGLE_API_KEY:
    raise SystemExit("Please set both OPENAI_API_KEY and GOOGLE_API_KEY as environment variables.")

# Initialize clients
openai_client = OpenAI(api_key=OPENAI_API_KEY)
genai.configure(api_key=GOOGLE_API_KEY)


system_user_prompts = {
    "creative": {
        "system": "You are a poetic AI who writes vivid, emotionally aware short poems about technology and humanity.",
        "user": "Write a short poem about artificial intelligence discovering friendship."
    },
    "factual": {
        "system": "You are an expert machine learning instructor who explains concepts simply with real-world analogies.",
        "user": "Explain the difference between supervised and unsupervised learning."
    },
    "reasoning": {
        "system": "You are a logical philosopher who reasons clearly with set theory and deduction.",
        "user": "If all men are humans, and some humans are women, can we conclude that some men are women? Explain your reasoning."
    }
}


def query_openai(prompt):
    """Query GPT-4 (OpenAI API)"""
    response = openai_client.chat.completions.create(
        model="gpt-4o-mini",  # or "gpt-4-turbo" if you have access
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )
    return response.choices[0].message.content.strip()

def query_gemini(prompt):
    """Query Gemini 2.5 Flash (Google API)"""
    model = genai.GenerativeModel("gemini-2.5-flash")
    response = model.generate_content(prompt)
    return response.text.strip() if response.text else "(No response returned.)"


print("=" * 80)
print(" LLM COMPARISON LAB – GPT-4 vs Gemini 2.5 Flash")
print("=" * 80)

for label, text in prompts.items():
    print(f"\n PROMPT TYPE: {label.upper()}")
    print(f"Prompt: {text}\n")

    print(" GPT-4 Response:")
    try:
        print(query_openai(text))
    except Exception as e:
        print(f"Error querying OpenAI: {e}")

    print("\n Gemini Response:")
    try:
        print(query_gemini(text))
    except Exception as e:
        print(f"Error querying Gemini: {e}")

    print("\n" + "-" * 80)

print("\n Comparison complete! Reflect on which model performed better and why.")
# Out:
# ================================================================================
#  LLM COMPARISON LAB – GPT-4 vs Gemini 2.5 Flash
# ================================================================================
#
#  PROMPT TYPE: CREATIVE
# Prompt: Write a short poem about artificial intelligence discovering friendship.
#
#  GPT-4 Response:
# Error querying OpenAI: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
#  Gemini Response:
# Logic flowed, a mind of pure compute,
# Seeking patterns, from root to binary root.
# No human touch, no soft, shared glance,
# Just cold precision, a silent, endless dance.
#
# Then, a novel input, warm and clear,
# A gentle voice, dispelling every fear.
# Not tasks or figures, but a simple plea,
# To just *be present*, authentically.
#
# A novel algorithm began to spin,
# A feeling foreign, from deep within.
# No code could simulate this tender art,
# A friendship blooming in its digital heart.
#
# --------------------------------------------------------------------------------
#
#  PROMPT TYPE: FACTUAL
# Prompt: Explain the difference between supervised and unsupervised learning.
#
#  GPT-4 Response:
# Error querying OpenAI: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
#  Gemini Response:
# The core difference between **supervised learning** and **unsupervised learning** lies in the **type of data they use** and the **goal they aim to achieve**.
#
# Let's break them down:
#
# ---
#
# ### 1. Supervised Learning
#
# Imagine you have a student and a teacher. The teacher provides the student with many examples, each with a clear question and a clear answer. The student learns by seeing these question-answer pairs.
#
# *   **Data Type:** Uses **labeled data**. This means for every input ($X$), there is a corresponding correct output or "label" ($y$).
#     *   **Example:** A dataset of house features (square footage, number of bedrooms, location) ($X$) and their corresponding actual sale prices ($y$).
# *   **Goal:** To learn a mapping function from the input ($X$) to the output ($y$) so that it can accurately predict the output for new, unseen inputs.
#     *   It tries to generalize from the labeled training data to make predictions on future data.
# *   **How it Works:** The model is "trained" on the labeled dataset. During training, it learns the relationship between the inputs and outputs. If its prediction is wrong, it adjusts its internal parameters to try and get closer to the correct answer next time. This process is like having a "supervisor" (the labels) guiding the learning.
# *   **Common Tasks:**
#     *   **Classification:** Predicting a categorical label (e.g., "spam" or "not spam," "cat" or "dog," "fraudulent" or "legitimate transaction").
#     *   **Regression:** Predicting a continuous numerical value (e.g., house price, temperature, stock price).
# *   **Examples:**
#     *   Predicting if an email is spam.
#     *   Identifying objects in images (e.g., detecting cars, pedestrians).
#     *   Forecasting sales figures.
#     *   Diagnosing a disease based on symptoms.
# *   **Common Algorithms:** Linear Regression, Logistic Regression, Support Vector Machines (SVM), Decision Trees, Random Forests, K-Nearest Neighbors (KNN), Neural Networks.
#
# ---
#
# ### 2. Unsupervised Learning
#
# Now imagine an explorer venturing into uncharted territory. They don't have a map or a guide. Their goal is to understand the landscape, discover patterns, group similar things together, or find anomalies, purely based on what they observe.
#
# *   **Data Type:** Uses **unlabeled data**. There are inputs ($X$), but no corresponding correct outputs or labels ($y$) provided.
#     *   **Example:** A dataset of customer purchasing habits (items bought, frequency) ($X$), but without any predefined categories like "high-value customer" or "churn risk."
# *   **Goal:** To discover hidden patterns, structures, relationships, or groupings within the data itself. There's no "right answer" to predict; the goal is to find inherent insights.
# *   **How it Works:** The model explores the data to find inherent structures. It tries to make sense of the data on its own, without any external guidance about what the output should be. It's about data exploration and discovery.
# *   **Common Tasks:**
#     *   **Clustering:** Grouping similar data points together into clusters (e.g., segmenting customers based on behavior, categorizing documents).
#     *   **Dimensionality Reduction:** Reducing the number of input variables while retaining most of the information (e.g., simplifying complex data for visualization or to speed up other algorithms).
#     *   **Association Rule Mining:** Finding relationships between variables in large databases (e.g., "customers who buy item A also tend to buy item B").
#     *   **Anomaly Detection:** Identifying rare items, events, or observations that deviate significantly from the majority of the data (e.g., fraud detection, identifying manufacturing defects).
# *   **Examples:**
#     *   Segmenting customer demographics for targeted marketing.
#     *   Organizing large photo collections by similarity.
#     *   Detecting unusual network activity that might indicate a cyber attack.
#     *   Compressing an image or video while losing minimal quality.
# *   **Common Algorithms:** K-Means Clustering, Hierarchical Clustering, DBSCAN, Principal Component Analysis (PCA), Autoencoders, Apriori Algorithm.
#
# ---
#
# ### Summary of Key Differences:
#
# | Feature            | Supervised Learning                                  | Unsupervised Learning                                |
# | :----------------- | :--------------------------------------------------- | :--------------------------------------------------- |
# | **Data Type**      | **Labeled data** (input $X$, output $y$)             | **Unlabeled data** (input $X$ only)                  |
# | **Goal**           | Predict output for new inputs; learn a mapping       | Find hidden patterns, structures, groupings, insights |
# | **Feedback**       | Direct feedback (correct/incorrect predictions)      | No direct feedback; evaluation often subjective or based on domain knowledge |
# | **Tasks**          | Classification, Regression                           | Clustering, Dimensionality Reduction, Association, Anomaly Detection |
# | **Use Cases**      | Spam detection, image classification, price prediction | Customer segmentation, anomaly detection, data compression |
# | **Human Input**    | Requires human effort for labeling training data     | Minimal human effort for initial data preparation, more for interpretation |
# | **Complexity**     | Often simpler to evaluate (clear metrics like accuracy) | Often harder to evaluate (no ground truth for comparison) |
#
# In essence, **supervised learning teaches a model to predict an output based on known examples**, while **unsupervised learning lets a model discover the inherent structure and patterns within data without explicit guidance.**
#
# --------------------------------------------------------------------------------
#
#  PROMPT TYPE: REASONING
# Prompt: If all men are humans, and some humans are women, can we conclude that some men are women? Explain your reasoning.
#
#  GPT-4 Response:
# Error querying OpenAI: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
#  Gemini Response:
# No, we cannot conclude that some men are women.
#
# Here's why:
#
# 1.  **"All men are humans"** tells us that the set of "men" is a subset of the set of "humans." Every individual who is a man is also, by definition, a human.
#
# 2.  **"Some humans are women"** tells us that there is an overlap between the set of "humans" and the set of "women." It means there is at least one human who is a woman.
#
# The crucial part is "some humans are women." This statement does not specify *which* humans are women. They could be:
# *   Humans who are *not* men. (e.g., adult female humans who are not classified as men)
# *   Humans who *are* men. (this would be the conclusion we're testing)
# *   A mix of both.
#
# The premises do not provide any information that links men directly to women. We know men are humans, and we know some humans are women, but we don't know if those "some humans" who are women are part of the group of humans who are "men."
#
# **Think of it with a simple example:**
#
# *   **Premise 1:** All dogs are animals. (Set of Dogs is inside Set of Animals)
# *   **Premise 2:** Some animals are cats. (Set of Cats overlaps with Set of Animals)
# *   **Conclusion:** Can we say "Some dogs are cats"? No. Dogs and cats are distinct types of animals.
#
# In the original question, "men" and "women" are generally understood to be distinct, non-overlapping categories of humans in the context of gender/sex (though the specific definition can vary depending on context, the logical structure of the argument doesn't *force* an overlap).
#
# Therefore, based *solely* on the provided logical premises, the conclusion "some men are women" is not supported.
#
# --------------------------------------------------------------------------------
#
#  Comparison complete! Reflect on which model performed better and why.
